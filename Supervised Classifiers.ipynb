# %% [markdown]
# # Supervised Classifiers
#
# Let's see how different supervised classifing learning algorithms have different decision spaces.

# %%
import warnings
warnings.simplefilter('ignore')

# %matplotlib inline

# %%
import Statistics.Classifiers as classifiers
# Out:
# Ptron Accuracy: 0.9073095905028677 +/- 0.0794174169434716 std
# k-NNLogit Accuracy: 0.9466506602641056 +/- 0.018980327094463827 std
# LDA Accuracy: 0.9071735360810992 +/- 0.06467445711122742 std
# QDA Accuracy: 0.946389222355609 +/- 0.05047189613182991 std
# DT Accuracy: 0.926781379218354 +/- 0.017010548225309022 std
# SVC Accuracy: 0.880234760570895 +/- 0.028754097269009515 std
# SVC RBF Accuracy: 0.953186607976524 +/- 0.020390428555912613 std
# AdaB Accuracy: 0.9399839935974389 +/- 0.0019605066319778775 std
# G-NB Accuracy: 0.8806375883686809 +/- 0.08336428507164198 std
# B-NB Accuracy: 0.926781379218354 +/- 0.017010548225309022 std
# RF Accuracy: 0.8334267040149393 +/- 0.04863599845133417 std

# %% [markdown]
# Yeah so cool :D
