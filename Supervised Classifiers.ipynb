# %% [markdown]
# # Supervised Classifiers
#
# Let's see how different supervised classifing learning algorithms have different decision spaces.

# %%
import warnings
warnings.simplefilter('ignore')

# %matplotlib inline

# %%
import Statistics.Classifiers as classifiers
# Out:
# k-NN Accuracy: 0.9537 +/- 0.0804 std, AUC: 0.9712
# Logit Accuracy: 0.9537 +/- 0.0804 std, AUC: 0.9895
# LDA Accuracy: 0.947 +/- 0.066 std, AUC: 0.9897
# QDA Accuracy: 0.947 +/- 0.066 std, AUC: 0.9893
# DT Accuracy: 0.92 +/- 0.0026 std, AUC: 0.9468
# SVC Accuracy: 0.9405 +/- 0.084 std, AUC: 0.9799
# SVC RBF Accuracy: 0.9405 +/- 0.084 std, AUC: 0.9764
# AdaB Accuracy: 0.933 +/- 0.0519 std, AUC: 0.9887
# G-NB Accuracy: 0.9536 +/- 0.0484 std, AUC: 0.9895
# B-NB Accuracy: 0.9403 +/- 0.0307 std, AUC: 0.9851
# RF Accuracy: 0.9669 +/- 0.0364 std, AUC: 0.988

# %% [markdown]
# Yeah so cool :D
