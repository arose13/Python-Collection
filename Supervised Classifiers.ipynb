# %% [markdown]
# # Supervised Classifiers
#
# Let's see how different supervised classifing learning algorithms have different decision spaces.

# %%
import warnings
warnings.simplefilter('ignore')

# %matplotlib inline

# %%
import Statistics.Classifiers as classifiers
# Out:
# Ptron Accuracy: 0.913311991463252 +/- 0.019006587403159286 std
# Logit Accuracy: 0.8730398826197145 +/- 0.08317546583264064 std
# LDA Accuracy: 0.9533226623982927 +/- 0.018886362793756786 std
# QDA Accuracy: 0.9467867146858744 +/- 0.01755824296990586 std
# DT Accuracy: 0.9263785514205681 +/- 0.040202532859506125 std
# SVC Accuracy: 0.9530558890222757 +/- 0.03867224666862071 std
# SVC RBF Accuracy: 0.9465199413098574 +/- 0.020197629175985284 std
# AdaB Accuracy: 0.9330452180872348 +/- 0.05194493682203223 std
# G-NB Accuracy: 0.9467867146858744 +/- 0.01755824296990586 std
# B-NB Accuracy: 0.7325997065492863 +/- 0.10098814587992633 std
# RF Accuracy: 0.9399839935974389 +/- 0.0019605066319778775 std

# %% [markdown]
# Yeah so cool :D
