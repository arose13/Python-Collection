# %% [markdown]
# # Supervised Classifiers
#
# Let's see how different supervised classifing learning algorithms have different decision spaces.

# %%
import warnings
warnings.simplefilter('ignore')

# %matplotlib inline

# %%
import Statistics.Classifiers as classifiers
# Out:
# k-NNLogit Accuracy: 0.9403 +/- 0.065 std, AUC: 0.9767
# LDA Accuracy: 0.9471 +/- 0.0484 std, AUC: 0.9939
# QDA Accuracy: 0.9467 +/- 0.0377 std, AUC: 0.9943
# DT Accuracy: 0.9533 +/- 0.0189 std, AUC: 0.9943
# SVC Accuracy: 0.9403 +/- 0.0307 std, AUC: 0.9472
# SVC RBF Accuracy: 0.9467 +/- 0.0377 std, AUC: 0.9893
# AdaB Accuracy: 0.9467 +/- 0.0377 std, AUC: 0.9881
# G-NB Accuracy: 0.9333 +/- 0.0189 std, AUC: 0.9889
# B-NB Accuracy: 0.9532 +/- 0.05 std, AUC: 0.9938
# RF Accuracy: 0.9464 +/- 0.0505 std, AUC: 0.9856

# %% [markdown]
# Yeah so cool :D
